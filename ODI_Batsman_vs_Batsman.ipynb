# %% [markdown]
# <a href="https://colab.research.google.com/github/Noobb0ne/ODI-Batsman-vs-Batsman-Stats-Comparison/blob/main/ODI_Batsman_vs_Batsman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('ODI_data.csv')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

# %%
df = df[df['Innings Runs Scored Num'] != '-']
df = df.dropna(subset = ['Innings Runs Scored Num'])
df['Innings Date'] = pd.to_datetime(df['Innings Date'])
df['year'] = df['Innings Date'].dt.year

# %%
df['Innings Runs Scored Num'] = df['Innings Runs Scored Num'].astype('int')
df['Innings Balls Faced'] = df['Innings Balls Faced'].astype('int') 
df['100'] = df['100'].astype('int') 
df["50"] = df["50"].astype('int')

# %%
print("Select any two batsmen:")
print("Sachin Tendulkar \tVirat Kohli \t        MS Dhoni \t        Rohit Sharma \t    Ricky Ponting")
print("AB de Villiers \t        Jacques Kallis \t        Sourav Ganguly \t        Rahul Dravid \t    Chris Gayle ")
print("Hashim Amla \t        Kumar Sangakkara \tSanath Jayasuriya \tSteve Smith \t    Kane Williamson")
print("Adam Gilchrist \t        Virendra Sehwag \tYuvraj Singh \t        Gautam Gambhir \t    Brendon McCullum")
print("Mahela Jayawardene \tBrian Lara \t        Joe Root \t        Ross Taylor \t    Babar Azam")
print("Viv Richards \t        Sunil Gavaskar \t        Gary Sobers \t        Steve Waugh \t    Ben Stokes")
print("Shikhar Dhawan \t        Inzamam Ul Haq \t        Dean Jones \t        KL Rahul \t    David Warner")
# Out:
# Select any two batsmen:
# Sachin Tendulkar 	Virat Kohli 	        MS Dhoni 	        Rohit Sharma 	    Ricky Ponting
# AB de Villiers 	        Jacques Kallis 	        Sourav Ganguly 	        Rahul Dravid 	    Chris Gayle
# Hashim Amla 	        Kumar Sangakkara 	Sanath Jayasuriya 	Steve Smith 	    Kane Williamson
# Adam Gilchrist 	        Virendra Sehwag 	Yuvraj Singh 	        Gautam Gambhir 	    Brendon McCullum
# Mahela Jayawardene 	Brian Lara 	        Joe Root 	        Ross Taylor 	    Babar Azam
# Viv Richards 	        Sunil Gavaskar 	        Gary Sobers 	        Steve Waugh 	    Ben Stokes
# Shikhar Dhawan 	        Inzamam Ul Haq 	        Dean Jones 	        KL Rahul 	    David Warner

# %%
bat1 = input()
bat2 = input()
bat1 = str(bat1)
bat2 = str(bat2)
# Out:
# Rohit Sharma
# Virat Kohli

# %%
if (bat1 == 'Sachin Tendulkar'):
  name = "SR Tendulkar"
  bat1_df = df[(df.year >= 1994) & (df.year <=2003)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'SR Tendulkar']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'India']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'SR Tendulkar']

elif (bat1 == 'Virat Kohli'):
  name = 'V Kohli'
  bat1_df = df[(df.year >= 2009) & (df.year <=2018)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'V Kohli']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'India']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'V Kohli']

elif (bat1 == 'MS Dhoni'):
  name = 'MS Dhoni'
  bat1_df = df[(df.year >= 2005) & (df.year <=2014)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'MS Dhoni']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'India']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'MS Dhoni']

elif (bat1 == 'Rohit Sharma'):
  name = 'RG Sharma'
  bat1_df = df[(df.year >= 2010) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'RG Sharma']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'India']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'RG Sharma']

elif (bat1 == 'Ricky Ponting'):
  name = 'RT Ponting'
  bat1_df = df[(df.year >= 2001) & (df.year <=2010)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'RT Ponting']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Australia']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'RT Ponting']

elif (bat1 == 'AB de Villiers'):
  name = 'AB de Villiers'
  bat1_df = df[(df.year >= 2007) & (df.year <=2016)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'AB de Villiers']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'South Africa']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'AB de Villiers']

elif (bat1 == 'Jacques Kallis'):
  name = 'JH Kallis'
  bat1_df = df[(df.year >= 1998) & (df.year <=2007)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'JH Kallis']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'South Africa']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'JH Kallis']

elif (bat1 == 'Sourav Ganguly'):
  name = 'SC Ganguly'
  bat1_df = df[(df.year >= 1997) & (df.year <=2007)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'SC Ganguly']
  country1 = str('India')
  bat1_tc = sum(bat1_df[bat1_df.Country == 'India']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'SC Ganguly']

elif (bat1 == 'Rahul Dravid'):
  name = 'RS Dravid'
  bat1_df = df[(df.year >= 1997) & (df.year <=2007)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'R Dravid']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'India']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'R Dravid']

elif (bat1 == 'Chris Gayle'):
  name = 'CH Gayle'
  bat1_df = df[(df.year >= 2001) & (df.year <=2010)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'CH Gayle']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'West Indies']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'CH Gayle']

elif (bat1 == 'Hashim Amla'):
  name = 'HM Amla'
  bat1_df = df[(df.year >= 2010) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'HM Amla']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'South Africa']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'HM Amla']

elif (bat1 == 'Kumar Sangakkara'):
  name = 'KC Sangakkara'
  bat1_df = df[(df.year >= 2006) & (df.year <=2015)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'KC Sangakkara']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Sri Lanka']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'KC Sangakarra']

elif (bat1 == 'Sanath Jayasuriya'):
  name = "ST Jayasuriya"
  bat1_df = df[(df.year >= 2000) & (df.year <=2009)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'ST Jayasuriya']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Sri Lanka']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'ST Jayasuriya']

elif (bat1 == 'Steve Smith'):
  name = 'SPD Smith'
  bat1_df = df[(df.year >= 2010) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'SPD Smith']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Australia']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'SPD Smith']

elif (bat1 == 'Kane Williamson'):
  name = 'KS Williamson'
  bat1_df = df[(df.year >= 2010) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'KS Williamson']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'New Zealand']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'KS Williamson']

elif (bat1 == 'Adam Gilchrist'):
  name = 'AC Gilchrist'
  bat1_df = df[(df.year >= 1998) & (df.year <=2007)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'AC Gilchrist']
  country1 = str(bat1_df.Country)
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Australia']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'AC Gilchrist']

elif (bat1 == 'Virender Sehwag'):
  name = 'Virender Sehwag'
  bat1_df = df[(df.year >= 2002) & (df.year <=2011)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'V Sehwag']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'India']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'V Sehwag']

elif (bat1 == 'Yuvraj Singh'):
  name = 'Y Singh'
  bat1_df = df[(df.year >= 2002) & (df.year <=2011)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'Yuvraj Singh']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'India']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'Yuvraj Singh']

elif (bat1 == 'Gautam Gambhir'):
  name = 'G Gambhir'
  bat1_df = df[(df.year >= 2003) & (df.year <=2012)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'G Gambhir']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'India']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'G Gambhir']

elif (bat1 == 'Brendon McCullum'):
  name = 'BB McCullum'
  bat1_df = df[(df.year >= 2006) & (df.year <=2015)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'BB McCullum']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'New Zealand']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'BB McCullum']

elif (bat1 == 'Mahela Jayawardene'):
  name = 'DPMD Jayawardene'
  bat1_df = df[(df.year >= 2006) & (df.year <=2015)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'DPMD Jayawardene']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Sri Lanks']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'DPMD Jayawardene']

elif (bat1 == 'Brian Lara'):
  name = 'BC Lara'
  bat1_df = df[(df.year >= 1992) & (df.year <=2001)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'BC Lara']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'West Indies']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'BC Lara']

elif (bat1 == 'Joe Root'):
  name = 'JE Root'
  bat1_df = df[(df.year >= 2012) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'JE Root']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'England']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'JE Root']

elif (bat1 == 'Ross Taylor'):
  name = 'LRPL Taylor'
  bat1_df = df[(df.year >= 2010) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'LRPL Taylor']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'New Zealand']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'LRPL Taylor']

elif (bat1 == 'Babar Azam'):
  name = 'Babar Azam'
  bat1_df = df[(df.year >= 2015) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'Babar Azam']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Pakistan']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'Babar Azam']

elif (bat1 == 'Viv Richards'):
  name = 'IVA Richards'
  bat1_df = df[(df.year >= 1979) & (df.year <=1988)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'IVA Richards']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'West Indies']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'IVA Richards']

elif (bat1 == 'Shikhar Dhawan'):
  name = 'S Dhawan'
  bat1_df = df[(df.year >= 2010) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'S Dhawan']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'India']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'S Dhawan']

elif (bat1 == 'Dean Jones'):
  name = 'DM Jones'
  bat1_df = df[(df.year >= 1985) & (df.year <=1994)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'DM Jones']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Australia']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'DM Jones']

elif (bat1 == 'David Warner'):
  name = 'DA Warner'
  bat1_df = df[(df.year >= 2011) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'DA Warner']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Australia']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'DA Warner']

elif (bat1 == 'Inzamam ul Haq'):
  name = 'Inzamam-ul-Haq'
  bat1_df = df[(df.year >= 1992) & (df.year <=2001)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'Inzamam-ul-Haq']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Pakistan']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'Inzamam-ul-Haq']
  
elif (bat1 == 'KL Rahul'):
  name = 'KL Rahul'
  bat1_df = df[(df.year >= 2016) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'KL Rahul']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'India']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'KL Rahul']

# %%
if (bat2 == 'Sachin Tendulkar'):
  name2 = 'SR Tendulkar'
  bat2_df = df[(df.year >= 1994) & (df.year <=2003)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'SR Tendulkar']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'India']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'SR Tendulkar']

elif (bat2 == 'Virat Kohli'):
  name2 = 'V Kohli'
  bat2_df = df[(df.year >= 2009) & (df.year <=2018)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'V Kohli']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'India']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'V Kohli']

elif (bat2 == 'MS Dhoni'):
  name2 = 'MS Dhoni'
  bat2_df = df[(df.year >= 2005) & (df.year <=2014)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'MS Dhoni']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'India']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'MS Dhoni']

elif (bat2 == 'Rohit Sharma'):
  name2 = 'RG Sharma'
  bat2_df = df[(df.year >= 2010) & (df.year <=2019)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'RG Sharma']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'India']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'RG Sharma']

elif (bat2 == 'Ricky Ponting'):
  name2 = "RT Ponting"
  bat2_df = df[(df.year >= 2001) & (df.year <=2010)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'RT Ponting']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'Australia']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat1_df['Innings Player'] != 'RT Ponting']

elif (bat2 == 'AB de Villiers'):
  name2 = 'AB de Villiers'
  bat2_df = df[(df.year >= 2007) & (df.year <=2016)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'AB de Villiers']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'South Africa']['Innings Runs Scored Num'])
  nba2_df = bat2_df[bat2_df['Innings Player'] != 'AB de Villiers']

elif (bat2 == 'Jacques Kallis'):
  name2 = 'JH Kallis'
  bat2_df = df[(df.year >= 1998) & (df.year <=2007)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'JH Kallis']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'South Africa']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'JH Kallis']

elif (bat2 == 'Sourav Ganguly'):
  name2 = 'SC Ganguly'
  bat2_df = df[(df.year >= 1997) & (df.year <=2007)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'SC Ganguly']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'India']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'SC Ganguly']

elif (bat2 == 'Rahul Dravid'):
  name2 = 'RS Dravid'
  bat2_df = df[(df.year >= 1997) & (df.year <=2007)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'R Dravid']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'India']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'R Dravid']

elif (bat2 == 'Chris Gayle'):
  name2 = 'CH Gayle'
  bat2_df = df[(df.year >= 2001) & (df.year <=2010)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'CH Gayle']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'West Indies']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'CH Gayle']

elif (bat2 == 'Hashim Amla'):
  name2 = 'HM Amla'
  bat2_df = df[(df.year >= 2010) & (df.year <=2019)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'HM Amla']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'South Africa']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'HM Amla']

elif (bat2 == 'Kumar Sangakkara'):
  name2 = 'KC Sangakkara'
  bat2_df = df[(df.year >= 2006) & (df.year <=2015)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'KC Sangakkara']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'Sri Lanka']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'KC Sangakarra']

elif (bat2 == 'Sanath Jayasuriya'):
  name2 = "ST Jayasuriya"
  bat2_df = df[(df.year >= 2000) & (df.year <=2009)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'ST Jayasuriya']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'Sri Lanka']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'ST Jayasuriya']

elif (bat2 == 'Steve Smith'):
  name2 = 'SPD Smith'
  bat2_df = df[(df.year >= 2010) & (df.year <=2019)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'SPD Smith']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'Australia']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'SPD Smith']

elif (bat2 == 'Kane Williamson'):
  name2 = 'KS Williamson'
  bat2_df = df[(df.year >= 2010) & (df.year <=2019)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'KS Williamson']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'New Zealand']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'KS Williamson']

elif (bat2 == 'Adam Gilchrist'):
  name2 = 'AC Gilchrist'
  bat2_df = df[(df.year >= 1998) & (df.year <=2007)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'AC Gilchrist']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'Australia']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'AC Gilchrist']

elif (bat2 == 'Virender Sehwag'):
  name2 = 'V Sehwag'
  bat2_df = df[(df.year >= 2002) & (df.year <=2011)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'V Sehwag']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'India']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'V Sehwag']

elif (bat2 == 'Yuvraj Singh'):
  name2 = 'Y Singh'
  bat2_df = df[(df.year >= 2002) & (df.year <=2011)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'Yuvraj Singh']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'India']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'Yuvraj']

elif (bat2 == 'Gautam Gambhir'):
  name2 = 'G Gambhir'
  bat2_df = df[(df.year >= 2003) & (df.year <=2012)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'G Gambhir']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'India']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'G Gambhir']

elif (bat2 == 'Brendon McCullum'):
  name2 = 'BB McCullum'
  bat2_df = df[(df.year >= 2006) & (df.year <=2015)]
  bat2_stat = bat2_df[bat2_df['Innings Player'] == 'BB McCullum']
  bat2_tc = sum(bat2_df[bat2_df.Country == 'New Zealand']['Innings Runs Scored Num'])
  nbat2_df = bat2_df[bat2_df['Innings Player'] != 'BB McCullum']

elif (bat2 == 'Mahela Jayawardene'):
  name = 'DPMD Jayawardene'
  bat1_df = df[(df.year >= 2006) & (df.year <=2015)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'DPMD Jayawardene']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Sri Lanks']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'DPMD Jayawardene']

elif (bat2 == 'Brian Lara'):
  name = 'BC Lara'
  bat1_df = df[(df.year >= 1992) & (df.year <=2001)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'BC Lara']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'West Indies']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'BC Lara']

elif (bat2 == 'Joe Root'):
  name = 'JE Root'
  bat1_df = df[(df.year >= 2012) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'JE Root']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'England']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'JE Root']

elif (bat2 == 'Ross Taylor'):
  name = 'LRPL Taylor'
  bat1_df = df[(df.year >= 2010) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'LRPL Taylor']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'New Zealand']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'LRPL Taylor']

elif (bat2 == 'Babar Azam'):
  name = 'Babar Azam'
  bat1_df = df[(df.year >= 2015) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'Babar Azam']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Pakistan']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'Babar Azam']

elif (bat2 == 'Viv Richards'):
  name = 'IVA Richards'
  bat1_df = df[(df.year >= 1979) & (df.year <=1988)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'IVA Richards']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'West Indies']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'IVA Richards']

elif (bat2 == 'Shikhar Dhawan'):
  name = 'S Dhawan'
  bat1_df = df[(df.year >= 2010) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'S Dhawan']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'India']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'S Dhawan']

elif (bat2 == 'Dean Jones'):
  name = 'DM Jones'
  bat1_df = df[(df.year >= 1985) & (df.year <=1994)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'DM Jones']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Australia']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'DM Jones']

elif (bat2 == 'David Warner'):
  name = 'DA Warner'
  bat1_df = df[(df.year >= 2011) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'DA Warner']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Australia']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'DA Warner']

elif (bat2 == 'Inzamam ul Haq'):
  name = 'Inzamam-ul-Haq'
  bat1_df = df[(df.year >= 1992) & (df.year <=2001)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'Inzamam-ul-Haq']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'Pakistan']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'Inzamam-ul-Haq']
  
elif (bat2 == 'KL Rahul'):
  name = 'KL Rahul'
  bat1_df = df[(df.year >= 2016) & (df.year <=2019)]
  bat1_stat = bat1_df[bat1_df['Innings Player'] == 'KL Rahul']
  bat1_tc = sum(bat1_df[bat1_df.Country == 'India']['Innings Runs Scored Num'])
  nbat1_df = bat1_df[bat1_df['Innings Player'] != 'KL Rahul']

# %%
print("Selected Players Stats")
print(" ",name,"'s")
print(" # Runs Per Innings: ",round(sum(bat1_stat['Innings Runs Scored Num'])/len(bat1_stat['Innings Runs Scored Num']),2))
print(" # Strike Rate: ",round(sum(bat1_stat['Innings Runs Scored Num'])/sum(bat1_stat['Innings Balls Faced'])*100,2))
print(" # 100s Scored: ",sum(bat1_stat['100']))
print(" # 50s Scored: ",sum(bat1_stat['50']))
print(" # Team Contribution: ",round(sum(bat1_stat['Innings Runs Scored Num'])/bat1_tc*100,2))
print(" ",name2,"'s")
print(' # Runs Per Innings: ',round(sum(bat2_stat['Innings Runs Scored Num'])/len(bat2_stat['Innings Runs Scored Num']),2))
print(' # Strike Rate: ',round(sum(bat2_stat['Innings Runs Scored Num'])/sum(bat2_stat['Innings Balls Faced'])*100,2))
print(' # 100s Scored: ',sum(bat2_stat['100']))
print(' # 50s Scored: ',sum(bat2_stat['50']))
print(' # Team Contribution: ',round(sum(bat2_stat['Innings Runs Scored Num'])/bat2_tc*100,2))
# Out:
# Selected Players Stats
#   RG Sharma 's
#  # Runs Per Innings:  46.4
#  # Strike Rate:  90.3
#  # 100s Scored:  27
#  # 50s Scored:  38
#  # Team Contribution:  13.99
#   V Kohli 's
#  # Runs Per Innings:  49.62
#  # Strike Rate:  93.47
#  # 100s Scored:  38
#  # 50s Scored:  47
#  # Team Contribution:  17.34

# %%
print('Selected Players Normalized Stats')
print(" ",name,"'s Normalized stats")
print(" # Runs Per Innings: ",round((sum(bat1_df['Innings Runs Scored Num'])/len(bat1_df))/(sum(nbat1_df['Innings Runs Scored Num'])/len(nbat1_df)),4))
print(" # Strike Rate: ",round(100*(sum(bat1_df['Innings Runs Scored Num'])/sum(bat1_df['Innings Balls Faced']))/(sum(nbat1_df['Innings Runs Scored Num'])/sum(nbat1_df['Innings Balls Faced'])),3))
print(" # Innings per 100: ",round(len(bat1_stat['Innings Runs Scored Num'])/sum(bat1_stat['100']),2))
print(" # Innings per 50: ",round(len(bat1_stat['Innings Runs Scored Num'])/sum(bat1_stat['50']),2))
#print(" # Team Contribution: ", round((sum(bat1_stat['Innings Runs Scored Num'])/sum(bat1_tc['Innings Runs Scored Num'])/(sum(nbat1_df[country1]['Innings Runs Scored Num'])/len(nbat1.Country == country))),2))
print(" ",name2,"'s Normalized stats")
print(" # Runs Per Innings: ",round((sum(bat2_df['Innings Runs Scored Num'])/len(bat2_df))/(sum(nbat2_df['Innings Runs Scored Num'])/len(nbat2_df)),4))
print(" # Strike Rate: ",round(100*(sum(bat2_df['Innings Runs Scored Num'])/sum(bat2_df['Innings Balls Faced']))/(sum(nbat2_df['Innings Runs Scored Num'])/sum(nbat2_df['Innings Balls Faced'])),3))
print(" # Innings per 100: ",round(len(bat2_stat['Innings Runs Scored Num'])/sum(bat2_stat['100']),2))
print(" # Innings per 50: ",round(len(bat2_stat['Innings Runs Scored Num'])/sum(bat2_stat['50']),2))
# Out:
# Selected Players Normalized Stats
#   RG Sharma 's Normalized stats
#  # Runs Per Innings:  1.0075
#  # Strike Rate:  100.116
#  # Innings per 100:  6.37
#  # Innings per 50:  4.53
#   V Kohli 's Normalized stats
#  # Runs Per Innings:  1.0104
#  # Strike Rate:  100.229
#  # Innings per 100:  5.34
#  # Innings per 50:  4.32
